# %%
import csv

data = [
    ("1928 (1st)", "DIRECTING (Dramatic Picture)", "Frank Borzage", "7th Heaven"),
    ("1929 (2nd)", "DIRECTING", "Frank Lloyd", "The Divine Lady"),
    ("1930 (3rd)", "DIRECTING", "Lewis Milestone", "All Quiet on the Western Front"),
    ("1931 (4th)", "DIRECTING", "Skippy", "Norman Taurog"),
    ("1932 (5th)", "DIRECTING", "Bad Girl", "Frank Borzage"),
    ("1933 (6th)", "DIRECTING", "Cavalcade", "Frank Lloyd"),
    ("1934 (7th)", "DIRECTING", "It Happened One Night", "Frank Capra"),
    ("1935 (8th)", "DIRECTING", "The Informer", "John Ford"),
    ("1936 (9th)", "DIRECTING", "Mr. Deeds Goes to Town", "Frank Capra"),
    ("1937 (10th)", "DIRECTING", "The Awful Truth", "Leo McCarey"),
    ("1938 (11th)", "DIRECTING", "You Can't Take It with You", "Frank Capra"),
    ("1939 (12th)", "DIRECTING", "Gone with the Wind", "Victor Fleming"),
    ("1940 (13th)", "DIRECTING", "The Grapes of Wrath", "John Ford"),
    ("1941 (14th)", "DIRECTING", "How Green Was My Valley", "John Ford"),
    ("1942 (15th)", "DIRECTING", "Mrs. Miniver", "William Wyler"),
    ("1943 (16th)", "DIRECTING", "Casablanca", "Michael Curtiz"),
    ("1944 (17th)", "DIRECTING", "Going My Way", "Leo McCarey"),
    ("1945 (18th)", "DIRECTING", "The Lost Weekend", "Billy Wilder"),
    ("1946 (19th)", "DIRECTING", "The Best Years of Our Lives", "William Wyler"),
    ("1947 (20th)", "DIRECTING", "Gentleman's Agreement", "Elia Kazan"),
    ("1948 (21st)", "DIRECTING", "The Treasure of the Sierra Madre", "John Huston"),
    ("1949 (22nd)", "DIRECTING", "A Letter to Three Wives", "Joseph L. Mankiewicz"),
    ("1950 (23rd)", "DIRECTING", "All about Eve", "Joseph L. Mankiewicz"),
    ("1951 (24th)", "DIRECTING", "A Place in the Sun", "George Stevens"),
    ("1952 (25th)", "DIRECTING", "The Quiet Man", "John Ford"),
    ("1953 (26th)", "DIRECTING", "From Here to Eternity", "Fred Zinnemann"),
    ("1954 (27th)", "DIRECTING", "On the Waterfront", "Elia Kazan"),
    ("1955 (28th)", "DIRECTING", "Marty", "Delbert Mann"),
    ("1956 (29th)", "DIRECTING", "Giant", "George Stevens"),
    ("1957 (30th)", "DIRECTING", "The Bridge on the River Kwai", "David Lean"),
    ("1958 (31st)", "DIRECTING", "Gigi", "Vincente Minnelli"),
    ("1959 (32nd)", "DIRECTING", "Ben-Hur", "William Wyler"),
    ("1960 (33rd)", "DIRECTING", "The Apartment", "Billy Wilder"),
    ("1961 (34th)", "DIRECTING", "West Side Story", "Robert Wise, Jerome Robbins"),
    ("1962 (35th)", "DIRECTING", "Lawrence of Arabia", "David Lean"),
    ("1963 (36th)", "DIRECTING", "Tom Jones", "Tony Richardson"),
    ("1964 (37th)", "DIRECTING", "My Fair Lady", "George Cukor"),
    ("1965 (38th)", "DIRECTING", "The Sound of Music", "Robert Wise"),
    ("1966 (39th)", "DIRECTING", "A Man for All Seasons", "Fred Zinnemann"),
    ("1967 (40th)", "DIRECTING", "The Graduate", "Mike Nichols"),
    ("1968 (41st)", "DIRECTING", "Oliver!", "Carol Reed"),
    ("1969 (42nd)", "DIRECTING", "Midnight Cowboy", "John Schlesinger"),
    ("1970 (43rd)", "DIRECTING", "Patton", "Franklin J. Schaffner"),
    ("1971 (44th)", "DIRECTING", "The French Connection", "William Friedkin"),
    ("1972 (45th)", "DIRECTING", "Cabaret", "Bob Fosse"),
    ("1973 (46th)", "DIRECTING", "The Sting", "George Roy Hill"),
    ("1974 (47th)", "DIRECTING", "The Godfather Part II", "Francis Ford Coppola"),
    ("1975 (48th)", "DIRECTING", "One Flew over the Cuckoo's Nest", "Milos Forman"),
    ("1976 (49th)", "DIRECTING", "Rocky", "John G. Avildsen"),
    ("1977 (50th)", "DIRECTING", "Annie Hall", "Woody Allen"),
    ("1978 (51st)", "DIRECTING", "The Deer Hunter", "Michael Cimino"),
    ("1979 (52nd)", "DIRECTING", "Kramer vs. Kramer", "Robert Benton"),
    ("1980 (53rd)", "DIRECTING", "Ordinary People", "Robert Redford"),
    ("1981 (54th)", "DIRECTING", "Reds", "Warren Beatty"),
    ("1982 (55th)", "DIRECTING", "Gandhi", "Richard Attenborough"),
    ("1983 (56th)", "DIRECTING", "Terms of Endearment", "James L. Brooks"),
    ("1984 (57th)", "DIRECTING", "Amadeus", "Milos Forman"),
    ("1985 (58th)", "DIRECTING", "Out of Africa", "Sydney Pollack"),
    ("1986 (59th)", "DIRECTING", "Platoon", "Oliver Stone"),
    ("1987 (60th)", "DIRECTING", "The Last Emperor", "Bernardo Bertolucci"),
    ("1988 (61st)", "DIRECTING", "Rain Man", "Barry Levinson"),
    ("1989 (62nd)", "DIRECTING", "Born on the Fourth of July", "Oliver Stone"),
    ("1990 (63rd)", "DIRECTING", "Dances With Wolves", "Kevin Costner"),
    ("1991 (64th)", "DIRECTING", "The Silence of the Lambs", "Jonathan Demme"),
    ("1992 (65th)", "DIRECTING", "Unforgiven", "Clint Eastwood"),
    ("1993 (66th)", "DIRECTING", "Schindler's List", "Steven Spielberg"),
    ("1994 (67th)", "DIRECTING", "Forrest Gump", "Robert Zemeckis"),
    ("1995 (68th)", "DIRECTING", "Braveheart", "Mel Gibson"),
    ("1996 (69th)", "DIRECTING", "The English Patient", "Anthony Minghella"),
    ("1997 (70th)", "DIRECTING", "Titanic", "James Cameron"),
    ("1998 (71st)", "DIRECTING", "Saving Private Ryan", "Steven Spielberg"),
    ("1999 (72nd)", "DIRECTING", "American Beauty", "Sam Mendes"),
    ("2000 (73rd)", "DIRECTING", "Traffic", "Steven Soderbergh"),
    ("2001 (74th)", "DIRECTING", "A Beautiful Mind", "Ron Howard"),
    ("2002 (75th)", "DIRECTING", "The Pianist", "Roman Polanski"),
    ("2003 (76th)", "DIRECTING", "The Lord of the Rings: The Return of the King", "Peter Jackson"),
    ("2004 (77th)", "DIRECTING", "Million Dollar Baby", "Clint Eastwood"),
    ("2005 (78th)", "DIRECTING", "Brokeback Mountain", "Ang Lee"),
    ("2006 (79th)", "DIRECTING", "The Departed", "Martin Scorsese"),
    ("2007 (80th)", "DIRECTING", "No Country for Old Men", "Joel Coen and Ethan Coen"),
    ("2008 (81st)", "DIRECTING", "Slumdog Millionaire", "Danny Boyle"),
    ("2009 (82nd)", "DIRECTING", "The Hurt Locker", "Kathryn Bigelow"),
    ("2010 (83rd)", "DIRECTING", "The King's Speech", "Tom Hooper"),
    ("2011 (84th)", "DIRECTING", "The Artist", "Michel Hazanavicius"),
    ("2012 (85th)", "DIRECTING", "Life of Pi", "Ang Lee"),
    ("2013 (86th)", "DIRECTING", "Gravity", "Alfonso Cuarón"),
    ("2014 (87th)", "DIRECTING", "Birdman or (The Unexpected Virtue of Ignorance)", "Alejandro G. Iñárritu"),
    ("2015 (88th)", "DIRECTING", "The Revenant", "Alejandro G. Iñárritu"),
    ("2016 (89th)", "DIRECTING", "La La Land", "Damien Chazelle"),
    ("2017 (90th)", "DIRECTING", "The Shape of Water", "Guillermo del Toro"),
    ("2018 (91st)", "DIRECTING", "Roma", "Alfonso Cuarón"),
    ("2019 (92nd)", "DIRECTING", "Parasite", "Bong Joon Ho"),
    ("2020 (93rd)", "DIRECTING", "Nomadland", "Chloé Zhao"),
    ("2021 (94th)", "DIRECTING", "The Power of the Dog", "Jane Campion"),
    ("2022 (95th)", "DIRECTING", "Everything Everywhere All at Once", "Daniel Kwan and Daniel Scheinert")
]

# %%
# Writing data to a CSV file
with open('directing_winners.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Year', 'Category', 'Director', 'Movie'])
    for i, item in enumerate(data):
        year = int(item[0].split()[0]) + 1
        new_year = f"{year} ({i + 1}st)"
        writer.writerow((new_year,) + item[1:])
